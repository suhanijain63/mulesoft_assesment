# %%
import sqlite3
connection=sqlite3.connect('demodb.db')
print('Connected to Database Successfully!')

cursor=connection.cursor()


sql=""" CREATE TABLE IF NOT EXISTS Movies(name TEXT PRIMARY KEY,actor TEXT,actress TEXT, director TEXT,YOR INTEGER) """

cursor.execute(sql)


cursor.execute(" INSERT INTO Movies VALUES ('Kabir Singh','Shahid Kapoor','Kiara Advani','Sandeep Reddy Vanga',2017)")
cursor.execute(" INSERT INTO Movies VALUES ('Sanju','Ranbir Kapoor','Anushka Sharma','Rajkumar Hirani',2018)")
cursor.execute(" INSERT INTO Movies VALUES ('Race','Saif Ali Khan','Katrina Kaif','Abbas & Mastan',2008)")
cursor.execute(" INSERT INTO Movies VALUES ('PK','Aamir khan','Anushka Sharma','Rajkumar Hirani',2014)")



cursor.execute("SELECT * FROM Movies")
data=cursor.fetchall()
print('\nAll the movies in the database are:\n')
print(data)



cursor.execute("SELECT * FROM Movies WHERE actor='Saif Ali Khan' ")
ans=cursor.fetchall()
print('\nThe movies with given actor are:\n')
print(ans)
# Out:
# Connected to Database Successfully!
#
# All the movies in the database are:
#
# [('Kabir Singh', 'Shahid Kapoor', 'Kiara Advani', 'Sandeep Reddy Vanga', 2017), ('Sanju', 'Ranbir Kapoor', 'Anushka Sharma', 'Rajkumar Hirani', 2018), ('Race', 'Saif Ali Khan', 'Katrina Kaif', 'Abbas & Mastan', 2008), ('PK', 'Aamir khan', 'Anushka Sharma', 'Rajkumar Hirani', 2014)]
#
# The movies with given actor are:
#
# [('Race', 'Saif Ali Khan', 'Katrina Kaif', 'Abbas & Mastan', 2008)]
